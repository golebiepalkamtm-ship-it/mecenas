# %%
import httpx

def check_ollama():
    try:
        with httpx.Client(timeout=5) as client:
            r = client.get('http://127.0.0.1:11434/')
            return 'ollama', r.status_code, r.text[:200]
    except Exception as e:
        return 'ollama error', str(e)

def check_supabase():
    headers = {
        'apikey': 'sbp_bc736171cdee952a5bad86f3b933a68bd2c39fe7',
        'Authorization': 'Bearer sbp_bc736171cdee952a5bad86f3b933a68bd2c39fe7'
    }
    try:
        with httpx.Client(timeout=5) as client:
            r = client.get('https://dhyvxspgsktpbjonejek.supabase.co/rest/v1/', headers=headers)
            return 'supabase', r.status_code, r.text[:200]
    except Exception as e:
        return 'supabase error', str(e)

print(check_ollama())
print(check_supabase())
